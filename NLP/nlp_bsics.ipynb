# %%
import nltk
print("NLTK installed")
# Out:
# NLTK installed

# %%
from nltk.tokenize import sent_tokenize

# %%
corpus ='''
hellow welcome to nlp !. this is used to process Human's language. give it a go.
'''

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# hellow welcome to nlp !.
# this is used to process Human's language.
# give it a go.

# %%
#Tokensization
#paragraph--> words
#sentence--> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['hellow',
#  'welcome',
#  'to',
#  'nlp',
#  '!',
#  '.',
#  'this',
#  'is',
#  'used',
#  'to',
#  'process',
#  'Human',
#  "'s",
#  'language',
#  '.',
#  'give',
#  'it',
#  'a',
#  'go',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['hellow', 'welcome', 'to', 'nlp', '!', '.']
# ['this', 'is', 'used', 'to', 'process', 'Human', "'s", 'language', '.']
# ['give', 'it', 'a', 'go', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['hellow',
#  'welcome',
#  'to',
#  'nlp',
#  '!.',
#  'this',
#  'is',
#  'used',
#  'to',
#  'process',
#  'Human',
#  "'",
#  's',
#  'language',
#  '.',
#  'give',
#  'it',
#  'a',
#  'go',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['hellow',
#  'welcome',
#  'to',
#  'nlp',
#  '!',
#  '.',
#  'this',
#  'is',
#  'used',
#  'to',
#  'process',
#  'Human',
#  "'s",
#  'language.',
#  'give',
#  'it',
#  'a',
#  'go',
#  '.']
